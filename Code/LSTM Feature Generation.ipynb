# %% [markdown]
# # Feature Generation for LSTM notebook: Progressive Rock and Others genres music classification

# %% [markdown]
# ## Importing Libraries.

# %%
# feature extractoring and preprocessing data
import librosa
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import os
from PIL import Image
import pathlib
import csv

# Preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

#Keras
import keras

import warnings
warnings.filterwarnings('ignore')
from google.colab import drive
drive.mount('/content/gdrive')

import math
# Out:
# Using TensorFlow backend.
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ## User Parameters
#
# **hop_length**: number of audio samples between successive frames
# **songsPath**: Folder location where all the songs are present
# **folders**:  Name of the folders in path which contains differnet genres of songs.
# **savePath**: Location where the extracted feature need to be saved
# **XFeatureFileName**: File name for the generated Input features
# **YFeatureFileName**: File name for the Labels corresponding to inputs

# %%
hop_length = 1024
songsPath = f'/content/gdrive/My Drive/ML test/Test Set/'
folders = 'Prog;Non-Prog'.split(';')
savePath = f'/content/gdrive/My Drive/My test/'
XFeatureFileName = "X_LSTM_Test.npy"
YFeatureFileName = "Y_LSTM_Test.npy"

# %% [markdown]
# ## Extracting features for train set
#
#
# We will extract
#
# * Mel-frequency cepstral coefficients (MFCC)(13 in number)
#
# Single song is split into multiple pieces of consecutive 200 time samples corresponding to top 13 mfcc feature. Number of pieces of songs is dependent on hop_length and sampling frequency. The label for each genrated piece is same as the original song. The generated input feature is a 3-D matrix of number_of_pieces_from_all_songs X 200 X 13
#
# Extracted features are saved to location provided by user

# %%
list_of_audiofiles = []
label = []
timeseries_length_list = []
for g in folders:
  for filename in os.listdir(songsPath + g):
    songname = songsPath + g + '/' + filename
    list_of_audiofiles.append(songname)
    folderName = g.replace(" ","")
    if(folderName != "Prog"):
      label.append(0)  # Non Prog Rock
    else:
      label.append(1)  # Prog Rock
print(len(list_of_audiofiles))
# Out:
# 201

# %%
def extract_training_audio_features(list_of_audiofiles):
        timeseries_length = 200 
        data = []
        target = []
        count = 0 
        for i, file in enumerate(list_of_audiofiles):
            print(i , file)
            y, sr = librosa.load(file)
            
            mfcc = librosa.feature.mfcc(y=y, sr=sr, hop_length=hop_length, n_mfcc=13)
            print(mfcc.T.shape)
            for samplesInt in range(0, mfcc.T.shape[0], timeseries_length):
              if samplesInt + timeseries_length < mfcc.T.shape[0]:
                data.append(mfcc.T[samplesInt:samplesInt+timeseries_length, :])
                count += 1
                target.append(label[i])
        X = np.asarray(data)
        return X, np.expand_dims(np.asarray(target), axis=1)

X,Y = extract_training_audio_features(list_of_audiofiles)
# Uncomment below lines of code to save feature set.
# with open( savePath + XFeatureFileName, 'wb') as f:
#   np.save(f, X)
# with open( savePath + YFeatureFileName, 'wb') as f:
#   np.save(f, Y)
# Out:
# 0 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/The Legend Of Ashitaka Theme.mp3
# (6492, 13)
# (32, 200, 13) (32, 1)

# %% [markdown]
# ## Extracting features for test  set
#
#
# We will extract
#
# * Mel-frequency cepstral coefficients (MFCC)(13 in number)
#
# Single song is split into multiple pieces of consecutive 200 time samples corresponding to top 13 mfcc feature. Number of pieces of songs is dependent on hop_length and sampling frequency. The label for each genrated piece is same as the original song. The generated input feature is a 4-D matrix of number_of_song X number_of_pieces_for_each_song X 200 X 13
#
# Extracted features are saved to location provided by user

# %%
def extract_test_audio_features(list_of_audiofiles):
        timeseries_length = 200 
        data = []
        target = []
        count = 0 
        for i, file in enumerate(list_of_audiofiles):
            print(i , file)
            y, sr = librosa.load(file)            
            songData = []
            mfcc = librosa.feature.mfcc(y=y, sr=sr, hop_length=hop_length, n_mfcc=13)
            print(mfcc.T.shape)
            for samplesInt in range(0, mfcc.T.shape[0], timeseries_length):
              if samplesInt + timeseries_length < mfcc.T.shape[0]:
                songData.append(mfcc.T[samplesInt:samplesInt+timeseries_length, :])
                count += 1
                target.append(label[i])            
            data.append(songData)
        X = np.asarray(data)
        return X, np.expand_dims(np.asarray(target), axis=1)

X,Y = extract_test_audio_features(list_of_audiofiles)
with open( savePath + XFeatureFileName, 'wb') as f:
  np.save(f, X)
with open( savePath + YFeatureFileName, 'wb') as f:
  np.save(f, Y)
# Out:
# 0 /content/gdrive/My Drive/ML test/Test Set/Prog/-04- Knots.mp3
# (5405, 13)
# 1 /content/gdrive/My Drive/ML test/Test Set/Prog/01 - 2112.mp3
# (26561, 13)
# 2 /content/gdrive/My Drive/ML test/Test Set/Prog/01 - Assault & Battery Part I.mp3
# (7253, 13)
# 3 /content/gdrive/My Drive/ML test/Test Set/Prog/01 - Beyond the Threshold, Pt. I (Helios Awakens).mp3
# (8187, 13)
# 4 /content/gdrive/My Drive/ML test/Test Set/Prog/01 - Songs From The Wood (2003 Digital Remaster).mp3
# (6365, 13)
# 5 /content/gdrive/My Drive/ML test/Test Set/Prog/01 - Stopa  1.mp3
# (2514, 13)
# 6 /content/gdrive/My Drive/ML test/Test Set/Prog/01 - Untouchable, Part 1.mp3
# (8002, 13)
# 7 /content/gdrive/My Drive/ML test/Test Set/Prog/01 Meeting of the Spirits.mp3
# (8861, 13)
# 8 /content/gdrive/My Drive/ML test/Test Set/Prog/01 Peaches En Regalia.mp3
# (4711, 13)
# 9 /content/gdrive/My Drive/ML test/Test Set/Prog/01-Opening Move.mp3
# (12528, 13)
# 10 /content/gdrive/My Drive/ML test/Test Set/Prog/01. Diana.mp3
# (5914, 13)
# 11 /content/gdrive/My Drive/ML test/Test Set/Prog/01. Hallogallo.mp3
# (13080, 13)
# 12 /content/gdrive/My Drive/ML test/Test Set/Prog/01. Ka$cade.mp3
# (6972, 13)
# 13 /content/gdrive/My Drive/ML test/Test Set/Prog/01. Oblivion_khaos.mp3
# (7420, 13)
# 14 /content/gdrive/My Drive/ML test/Test Set/Prog/01. Simple Boy.mp3
# (7479, 13)
# 15 /content/gdrive/My Drive/ML test/Test Set/Prog/01. The Light.mp3
# (20084, 13)
# 16 /content/gdrive/My Drive/ML test/Test Set/Prog/01. The Same River.mp3
# (15545, 13)
# 17 /content/gdrive/My Drive/ML test/Test Set/Prog/01.Prologue - Autumn.flac
# (14405, 13)
# 18 /content/gdrive/My Drive/ML test/Test Set/Prog/02 - Desert Girl.mp3
# (7881, 13)
# 19 /content/gdrive/My Drive/ML test/Test Set/Prog/02 - Song for America.mp3
# (12987, 13)
# 20 /content/gdrive/My Drive/ML test/Test Set/Prog/02 - Xanadu.mp3
# (14318, 13)
# 21 /content/gdrive/My Drive/ML test/Test Set/Prog/02-Mountain Of Fruits And Flowers.mp3
# (4236, 13)
# 22 /content/gdrive/My Drive/ML test/Test Set/Prog/02. This Film Might Change Your Life.mp3
# (11683, 13)
# 23 /content/gdrive/My Drive/ML test/Test Set/Prog/02. Time Is Monet.mp3
# (12577, 13)
# 24 /content/gdrive/My Drive/ML test/Test Set/Prog/03 - Symphony X - Fallen.mp3
# (7560, 13)
# 25 /content/gdrive/My Drive/ML test/Test Set/Prog/03 A Plague of Lighthouse Keepers.mp3
# (29989, 13)
# 26 /content/gdrive/My Drive/ML test/Test Set/Prog/03 Paralised Civilization.mp3
# (12252, 13)
# 27 /content/gdrive/My Drive/ML test/Test Set/Prog/03 Starship Trooper- Life Seeker , Disillusion , Wurm.flac
# (12288, 13)
# 28 /content/gdrive/My Drive/ML test/Test Set/Prog/03. Little Man.mp3
# (6001, 13)
# 29 /content/gdrive/My Drive/ML test/Test Set/Prog/04 - Halleluhwah.flac
# (23961, 13)
# 30 /content/gdrive/My Drive/ML test/Test Set/Prog/04 - No Part Of Me.mp3
# (7419, 13)
# 31 /content/gdrive/My Drive/ML test/Test Set/Prog/04-In The Land Of Grey And Pink.mp3
# (6470, 13)
# 32 /content/gdrive/My Drive/ML test/Test Set/Prog/04-Stranger In Your Soul_Resampled.mp3
# (38765, 13)
# 33 /content/gdrive/My Drive/ML test/Test Set/Prog/04. Selkies- The Endless Obsession.mp3
# (9545, 13)
# 34 /content/gdrive/My Drive/ML test/Test Set/Prog/04_Birthright.mp3
# (7852, 13)
# 35 /content/gdrive/My Drive/ML test/Test Set/Prog/05 - Jurassic Shift.mp3
# (14317, 13)
# 36 /content/gdrive/My Drive/ML test/Test Set/Prog/05 - Ouroboros.mp3
# (22467, 13)
# 37 /content/gdrive/My Drive/ML test/Test Set/Prog/05 - Those Golden Wings.mp3
# (14642, 13)
# 38 /content/gdrive/My Drive/ML test/Test Set/Prog/05-Son Of There's No Place Like Homerton.mp3
# (13155, 13)
# 39 /content/gdrive/My Drive/ML test/Test Set/Prog/05. Bortglömda Gårdar.flac
# (18164, 13)
# 40 /content/gdrive/My Drive/ML test/Test Set/Prog/05. Guardian Of My Soul.mp3
# (16402, 13)
# 41 /content/gdrive/My Drive/ML test/Test Set/Prog/05. Histoires Sans Paroles.mp3
# (22218, 13)
# 42 /content/gdrive/My Drive/ML test/Test Set/Prog/05. When the Water Breaks.mp3
# (21914, 13)
# 43 /content/gdrive/My Drive/ML test/Test Set/Prog/05.Harvest_of_Souls.mp3
# (31649, 13)
# 44 /content/gdrive/My Drive/ML test/Test Set/Prog/05_Shine On You Crazy Diamond II.mp3
# (16144, 13)
# 45 /content/gdrive/My Drive/ML test/Test Set/Prog/05_Turn of the Century.mp3
# (8396, 13)
# 46 /content/gdrive/My Drive/ML test/Test Set/Prog/06  Ashes Are  Burning .mp3
# (14662, 13)
# 47 /content/gdrive/My Drive/ML test/Test Set/Prog/06 - Echoes.mp3
# (30333, 13)
# 48 /content/gdrive/My Drive/ML test/Test Set/Prog/06 Mekanik Kommandoh.mp3
# (5359, 13)
# 49 /content/gdrive/My Drive/ML test/Test Set/Prog/06 The Main Monkey Business.mp3
# (7784, 13)
# 50 /content/gdrive/My Drive/ML test/Test Set/Prog/06-duel_of_the_jester_and_the_tyrant_320_lame_cbr.mp3
# (14788, 13)
# 51 /content/gdrive/My Drive/ML test/Test Set/Prog/06-Happy Nightmare (Mescaline).mp3
# (5188, 13)
# 52 /content/gdrive/My Drive/ML test/Test Set/Prog/06. Milliontown.mp3
# (34354, 13)
# 53 /content/gdrive/My Drive/ML test/Test Set/Prog/06. Part VI.mp3
# (9668, 13)
# 54 /content/gdrive/My Drive/ML test/Test Set/Prog/07 - Nights In White Satin.mp3
# (9680, 13)
# 55 /content/gdrive/My Drive/ML test/Test Set/Prog/07 - The Final Thing On My Mind.mp3
# (12783, 13)
# 56 /content/gdrive/My Drive/ML test/Test Set/Prog/07 A Louse Is Not A Home.mp3
# (16176, 13)
# 57 /content/gdrive/My Drive/ML test/Test Set/Prog/07. Escalator Shrine.mp3
# (16388, 13)
# 58 /content/gdrive/My Drive/ML test/Test Set/Prog/07. Incantation (Part 1).mp3
# (8336, 13)
# 59 /content/gdrive/My Drive/ML test/Test Set/Prog/07. ShutDOWN.mp3
# (13453, 13)
# 60 /content/gdrive/My Drive/ML test/Test Set/Prog/07_Genesis_The Fountain of Salmacis.mp3
# (10200, 13)
# 61 /content/gdrive/My Drive/ML test/Test Set/Prog/08 - Ebb & Flow.mp3
# (9191, 13)
# 62 /content/gdrive/My Drive/ML test/Test Set/Prog/08 - I Spy.mp3
# (7860, 13)
# 63 /content/gdrive/My Drive/ML test/Test Set/Prog/08 - Lady Fantasy.mp3
# (20792, 13)
# 64 /content/gdrive/My Drive/ML test/Test Set/Prog/08 - Spectral Mornings (2005 Digital Remaster).mp3
# (8552, 13)
# 65 /content/gdrive/My Drive/ML test/Test Set/Prog/08 .3 1.m4a
# (7011, 13)
# 66 /content/gdrive/My Drive/ML test/Test Set/Prog/08 Heavy Horses.mp3
# (11650, 13)
# 67 /content/gdrive/My Drive/ML test/Test Set/Prog/08 Los Endos.mp3
# (7460, 13)
# 68 /content/gdrive/My Drive/ML test/Test Set/Prog/08 Suite Sister Mary.mp3
# (13776, 13)
# 69 /content/gdrive/My Drive/ML test/Test Set/Prog/08. Visions -remastered 2017-.mp3
# (29021, 13)
# 70 /content/gdrive/My Drive/ML test/Test Set/Prog/08_-_opeth_-_blackwater park_-_blackwater park.mp3
# (15684, 13)
# 71 /content/gdrive/My Drive/ML test/Test Set/Prog/08_-_shadow_of_the_hierophant_320_lame_cbr.mp3
# (15180, 13)
# 72 /content/gdrive/My Drive/ML test/Test Set/Prog/08_The_Devil's_Triangle_Part_II.mp3
# (5179, 13)
# 73 /content/gdrive/My Drive/ML test/Test Set/Prog/09 Heart Of The Sunrise.mp3
# (14916, 13)
# 74 /content/gdrive/My Drive/ML test/Test Set/Prog/09_Lateralus.mp3
# (12149, 13)
# 75 /content/gdrive/My Drive/ML test/Test Set/Prog/09_Time Flies.mp3
# (15088, 13)
# 76 /content/gdrive/My Drive/ML test/Test Set/Prog/1 robert wyatt SEA SONG.mp3
# (8443, 13)
# 77 /content/gdrive/My Drive/ML test/Test Set/Prog/10 Peace To The Mountain.mp3
# (8473, 13)
# 78 /content/gdrive/My Drive/ML test/Test Set/Prog/101-marillion-the_invisible_man-sns.mp3
# (17608, 13)
# 79 /content/gdrive/My Drive/ML test/Test Set/Prog/103 Moon In June.mp3
# (24720, 13)
# 80 /content/gdrive/My Drive/ML test/Test Set/Prog/11 - On That Note.flac
# (11827, 13)
# 81 /content/gdrive/My Drive/ML test/Test Set/Prog/13 - Beyond the Pale.mp3
# (12957, 13)
# 82 /content/gdrive/My Drive/ML test/Test Set/Prog/17-Toxicological Whispering.mp3
# (10126, 13)
# 83 /content/gdrive/My Drive/ML test/Test Set/Prog/4 Master Builder.flac
# (8193, 13)
# 84 /content/gdrive/My Drive/ML test/Test Set/Prog/Barclay James Harvest - Mocking Bird.mp3
# (8600, 13)
# 85 /content/gdrive/My Drive/ML test/Test Set/Prog/Big Big Train - English Electric (Part Two) - 01 - East Coast Racer.mp3
# (20307, 13)
# 86 /content/gdrive/My Drive/ML test/Test Set/Prog/captain beefheart - trout mask replica - 05 - hair pie- bake .mp3
# (6434, 13)
# 87 /content/gdrive/My Drive/ML test/Test Set/Prog/Dark Light - Sinkin' Deep.mp3
# (8801, 13)
# 88 /content/gdrive/My Drive/ML test/Test Set/Prog/De-Loused In The Comatorium-The Mars Volta-07-Cicatriz ESP.mp3
# (16124, 13)
# 89 /content/gdrive/My Drive/ML test/Test Set/Prog/Devin Townsend Project - Kingdom.mp3
# (7087, 13)
# 90 /content/gdrive/My Drive/ML test/Test Set/Prog/Dream Theater - Metropolis, Pt. 1- The Miracle and the Sleeper.mp3
# (12322, 13)
# 91 /content/gdrive/My Drive/ML test/Test Set/Prog/Impressioni di settembre.mp3
# (7417, 13)
# 92 /content/gdrive/My Drive/ML test/Test Set/Prog/Kraftwerk - 01 - Autobahn.mp3
# (29420, 13)
# 93 /content/gdrive/My Drive/ML test/Test Set/Prog/L'evoluzione.mp3
# (18067, 13)
# 94 /content/gdrive/My Drive/ML test/Test Set/Prog/MIKE OLDFIELD - Part One (Ommadawn).mp3
# (25053, 13)
# 95 /content/gdrive/My Drive/ML test/Test Set/Prog/Rick Wakeman-The Six Wives of Henry VIII-05-Anne Boleyn 'The Day Thou Gavest Lord Hath Ended'.flac
# (8543, 13)
# 96 /content/gdrive/My Drive/ML test/Test Set/Prog/The Dear Hunter - 06 - A Night on the Town.flac
# (11632, 13)
# 97 /content/gdrive/My Drive/ML test/Test Set/Prog/The Flower Kings - 1997 Stardust We Are CD2 - 11 - Stardust We Are.mp3
# (32380, 13)
# 98 /content/gdrive/My Drive/ML test/Test Set/Prog/The Gathering - 09 - Saturnine.mp3
# (6711, 13)
# 99 /content/gdrive/My Drive/ML test/Test Set/Prog/The Power To Believe-King Crimson-07-The Power To Believe II.mp3
# (9988, 13)
# 100 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/01 - Beds Are Burning.mp3
# (5523, 13)
# 101 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/01 - Djobi Djoba.mp3
# (4407, 13)
# 102 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/01 - Heat Of The Moment.mp3
# (4903, 13)
# 103 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/01 - Highway Star.mp3
# (7936, 13)
# 104 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/01 - Nina Simone -  - Be My Husband .mp3
# (4376, 13)
# 105 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/01 - Prelude and The Sound of Music.mp3
# (4592, 13)
# 106 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/01 - Run Away With Me.mp3
# (5412, 13)
# 107 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/01 Dance Yrself Clean.mp3
# (11545, 13)
# 108 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/01 Everyone's At It (Album Version).mp3
# (5572, 13)
# 109 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/01 Jacqueline.mp3
# (4932, 13)
# 110 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/01 Penguin Cafe Single.mp3
# (8193, 13)
# 111 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/01 the american metaphysical circus.mp3
# (6399, 13)
# 112 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/01-Life's Greatest Fool.mp3
# (6131, 13)
# 113 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/01. Redbone - Come And Get Your Love.mp3
# (4576, 13)
# 114 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/01_Mere Sapnon Ki Rani.mp3
# (6411, 13)
# 115 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/01_Mind Ecology.mp3
# (7491, 13)
# 116 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/02 - James Brown.mp3
# (4322, 13)
# 117 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/02 All Mine.mp3
# (5219, 13)
# 118 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/02 I Can Do Anything.m4a
# (4109, 13)
# 119 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/02 Paranoid.m4a
# (3627, 13)
# 120 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/02 QUEENS OF THE STONE AGE-NO ONE KNOWS.mp3
# (6004, 13)
# 121 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/02 Sweet Lullaby.mp3
# (5034, 13)
# 122 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/02 That's All.mp3
# (5735, 13)
# 123 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/02. Cover Me.mp3
# (4540, 13)
# 124 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/02. Death Cab for Cutie - Soul Meets Body.ogg
# (4973, 13)
# 125 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/02. None Of Them Knew They Were Robots.mp3
# (7838, 13)
# 126 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/02. Untitled 02 (06.23.2014).mp3
# (5575, 13)
# 127 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/03 - Mikrokosmos.mp3
# (4829, 13)
# 128 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/03 - Three Ragas in 'D' Minor.mp3
# (15009, 13)
# 129 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/03 - What the Water Gave Me.mp3
# (7180, 13)
# 130 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/03 Boys Don't Cry.mp3
# (3340, 13)
# 131 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/03 I Am a God (feat. God).m4a
# (4986, 13)
# 132 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/03 Katy Song.mp3
# (10830, 13)
# 133 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/03 Nightmares On Wax - Pipes Honour.mp3
# (11748, 13)
# 134 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/03 Sweet Talkin' Woman.mp3
# (4812, 13)
# 135 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/03-Birthday.mp3
# (5140, 13)
# 136 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/03-Sweet Blindness.mp3
# (3472, 13)
# 137 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/03. Teardrop.mp3
# (7123, 13)
# 138 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/03. Tessellate.mp3
# (3935, 13)
# 139 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/03.-DJ-Snake---Let-Me-Love-You.mp3
# (4435, 13)
# 140 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/03_vicious_delicious.mp3
# (9581, 13)
# 141 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/04 - Out Of The Blue.mp3
# (6179, 13)
# 142 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/04 - Song of Destiny.mp3
# (20137, 13)
# 143 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/04 Boy In The Moon.mp3
# (10759, 13)
# 144 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/04-Fade Away (And Radiate).mp3
# (5222, 13)
# 145 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/04. Ascension (Don't Ever Wonder).mp3
# (7451, 13)
# 146 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/04. Let's Pretend We're Married.mp3
# (9509, 13)
# 147 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/05 - Hey Lawdy Mama.mp3
# (3799, 13)
# 148 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/05 - In Your Eyes.mp3
# (7098, 13)
# 149 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/05 - Moonwind.mp3
# (10759, 13)
# 150 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/05 - Nick Cave & The Bad Seeds - Fifteen Feet Of Pure White Snow.mp3
# (7252, 13)
# 151 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/05 - The Temple On the Edge of Time.mp3
# (7559, 13)
# 152 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/05 I Left My Wallet In El Segundo.mp3
# (5355, 13)
# 153 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/05-miles_runs_the_voodoo_down_320_lame_cbr.mp3
# (18193, 13)
# 154 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/05-Territories.mp3
# (8161, 13)
# 155 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/05.King of Hollywood.mp3
# (8369, 13)
# 156 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/06 - Between Love & Hate.mp3
# (4218, 13)
# 157 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/06 - Merge.mp3
# (8278, 13)
# 158 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/06 - Physical.mp3
# (4760, 13)
# 159 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/06 - Video Girl.mp3
# (4902, 13)
# 160 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/06 Angel Tears - Inshalla (Ya Salam).mp3
# (5874, 13)
# 161 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/06 Marvins Room - Buried Alive (Interlude) (Feat. Kendrick Lamar).mp3
# (10667, 13)
# 162 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/06 TITO PUENTE-HONG KONG MAMBO.mp3
# (4918, 13)
# 163 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/06.-Jax-Jones-feat.-RAYE--You-Don't-Know-Me.mp3
# (4589, 13)
# 164 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/07 - Signals (Orchestrion Sketch).mp3
# (14788, 13)
# 165 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/07 - Speed Of Sound.mp3
# (6212, 13)
# 166 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/07 By Myself.m4a
# (4088, 13)
# 167 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/07_Sinister Grains.mp3
# (7997, 13)
# 168 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/08 - Supersonic Rocket Ship.mp3
# (4534, 13)
# 169 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/08 - When the Levee Breaks.mp3
# (9278, 13)
# 170 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/08-oneohtrix_point_never-computer_vision-kouala.mp3
# (3123, 13)
# 171 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/09 - Intimate Grandeur.mp3
# (8714, 13)
# 172 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/09 Ascot Gavotte.mp3
# (4072, 13)
# 173 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/09 Do You Realize--.mp3
# (4582, 13)
# 174 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/09. Tel Aviv.mp3
# (6834, 13)
# 175 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/1-01 It's Not Over.m4a
# (4631, 13)
# 176 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/10 I.mp3
# (2695, 13)
# 177 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/10-Music And Politics.mp3
# (5197, 13)
# 178 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/11 - Hello Earth.mp3
# (8034, 13)
# 179 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/11 Jeru The Damaja - Come Clean.mp3
# (6398, 13)
# 180 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/12-modest_mouse-spitting_venom.mp3
# (10921, 13)
# 181 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/13 - Neodammerung.mp3
# (7743, 13)
# 182 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/2 - Arctic Monkeys - One Point Perspective.mp3
# (4493, 13)
# 183 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/20. De La Soul - Me Myself And I.mp3
# (4957, 13)
# 184 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/21Henry Mancini - Baby Elephant Walk.mp3
# (3552, 13)
# 185 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/22 - Dear Mr. Fantasy.mp3
# (7312, 13)
# 186 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/3. My Beautiful Dark Twisted Fantasy - POWER.mp3
# (6291, 13)
# 187 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/55. Rosalía - Malamente.mp3
# (3219, 13)
# 188 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/9-08 Strawberry Fields Forever.mp3
# (5327, 13)
# 189 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/A Dream In Red Mansions.mp3
# (8063, 13)
# 190 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/Bambola.mp3
# (10250, 13)
# 191 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/Bauhaus - Mask - 02.mp3
# (5017, 13)
# 192 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/Beethoven_Symphony_5.mp3
# (42655, 13)
# 193 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/Chelsea Dagger.mp3
# (4638, 13)
# 194 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/Gustav Mahler - Symphony no.3 - 06 - Langsam--Ruhevoll--Empfunden.flac
# (34403, 13)
# 195 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/into the void.mp3
# (6231, 13)
# 196 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/John Williams-The Phantom Menace-0 - Duel of the Fates.mp3
# (5471, 13)
# 197 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/Moby---Extreme-Ways-(Bourne's-Ultimatum).mp3
# (5641, 13)
# 198 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/Oingo-Boingo---Weird-Science-(Extended-Dance-Mix).mp3
# (8351, 13)
# 199 /content/gdrive/My Drive/ML test/Test Set/Non-Prog/Radiohead - Spectre.mp3
# (4293, 13)
